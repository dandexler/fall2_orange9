# %%
import pandas as pd
import numpy as np
import os
import csv

os.chdir(r"C:\Users\karud\Documents\MSA_Fall2\Visualization")

# %%
tblAcc = pd.read_csv("Accident_EDITED.csv")
tblAcc.head(10)
# Out:
#    Index    STATE  COUNTY    MONTH  DAY HOUR MINUTE  VE_FORMS  PERSONS  PEDS  \
# 0      1  Alabama     117  January    1    5     24         1        5     1
# 1      2  Alabama       1  January    3   18     35         1        1     0
# 2      3  Alabama      73  January    9    8     45         1        1     0
# 3      4  Alabama      21  January    6    3     25         1        1     0
# 4      5  Alabama      53  January    4    9     35         3        3     0
# 5      6  Alabama      97  January    1   19     15         1        6     1
# 6      7  Alabama      49  January    1   19     50         1        2     0
# 7      8  Alabama      15  January    9    0     45         1        1     0
# 8      9  Alabama      89  January    3   18     10         1        4     0
# 9     10  Alabama     103  January    6    2     50         1        3     0
#
#    ... TWAY_ID2 VE_TOTAL WEATHER1 WEATHER2 WRK_ZONE TYP_INT PVH_INVL  \
# 0  ...      NaN      NaN      NaN      NaN      NaN     NaN      NaN
# 1  ...      NaN      NaN      NaN      NaN      NaN     NaN      NaN
# 2  ...      NaN      NaN      NaN      NaN      NaN     NaN      NaN
# 3  ...      NaN      NaN      NaN      NaN      NaN     NaN      NaN
# 4  ...      NaN      NaN      NaN      NaN      NaN     NaN      NaN
# 5  ...      NaN      NaN      NaN      NaN      NaN     NaN      NaN
# 6  ...      NaN      NaN      NaN      NaN      NaN     NaN      NaN
# 7  ...      NaN      NaN      NaN      NaN      NaN     NaN      NaN
# 8  ...      NaN      NaN      NaN      NaN      NaN     NaN      NaN
# 9  ...      NaN      NaN      NaN      NaN      NaN     NaN      NaN
#
#   PERNOTMVIT PERMVIT RUR_URB
# 0        NaN     NaN     NaN
# 1        NaN     NaN     NaN
# 2        NaN     NaN     NaN
# 3        NaN     NaN     NaN
# 4        NaN     NaN     NaN
# 5        NaN     NaN     NaN
# 6        NaN     NaN     NaN
# 7        NaN     NaN     NaN
# 8        NaN     NaN     NaN
# 9        NaN     NaN     NaN
#
# [10 rows x 46 columns]

# %%
# only want NC and years 2010-2017
#TODO: how to combine both filters in one step?
tblAccSub = tblAcc[tblAcc.STATE == 'North Carolina'] 
tblAccSub = tblAccSub[tblAccSub.YEAR > 2009]
tblAccSub.head(10)
# Out:
#          Index           STATE  COUNTY    MONTH  DAY             HOUR MINUTE  \
# 390071  390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 390072  390073  North Carolina      25  January    8  11:00pm-11:59pm     19
# 390073  390074  North Carolina      47  January    8    9:00pm-9:59pm     21
# 390074  390075  North Carolina      51  January    6    5:00am-5:59am     44
# 390075  390076  North Carolina      69  January    1    2:00am-2:59am     32
# 390076  390077  North Carolina      77  January   14    6:00am-6:59am     31
# 390077  390078  North Carolina      85  January   12    3:00am-3:59am     30
# 390078  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 390079  390080  North Carolina     103  January   10    8:00pm-8:59pm     56
# 390080  390081  North Carolina     129  January   12    9:00am-9:59am     50
#
#         VE_FORMS  PERSONS  PEDS  ...      TWAY_ID2 VE_TOTAL          WEATHER1  \
# 390071         2        2     0  ...           NaN      2.0             Clear
# 390072         1        2     0  ...           NaN      1.0             Clear
# 390073         1        1     0  ...           NaN      1.0             Clear
# 390074         2        2     0  ...  HELEN STREET      2.0             Clear
# 390075         1        1     0  ...           NaN      1.0  Fog, Smog, Smoke
# 390076         3        3     0  ...           NaN      3.0             Clear
# 390077         2        3     0  ...           NaN      2.0             Clear
# 390078         2        5     0  ...       RP-1508      2.0             Clear
# 390079         2        2     0  ...           NaN      2.0             Clear
# 390080         1        1     1  ...           NaN      1.0             Clear
#
#                                     WEATHER2 WRK_ZONE                TYP_INT  \
# 390071  No Additional Atmospheric Conditions     None    Not an Intersection
# 390072  No Additional Atmospheric Conditions     None    Not an Intersection
# 390073  No Additional Atmospheric Conditions     None    Not an Intersection
# 390074  No Additional Atmospheric Conditions     None  Four-Way Intersection
# 390075  No Additional Atmospheric Conditions     None    Not an Intersection
# 390076  No Additional Atmospheric Conditions     None    Not an Intersection
# 390077  No Additional Atmospheric Conditions     None    Not an Intersection
# 390078  No Additional Atmospheric Conditions     None         T-Intersection
# 390079  No Additional Atmospheric Conditions     None    Not an Intersection
# 390080  No Additional Atmospheric Conditions     None    Not an Intersection
#
#        PVH_INVL PERNOTMVIT PERMVIT RUR_URB
# 390071      NaN        NaN     NaN     NaN
# 390072      NaN        NaN     NaN     NaN
# 390073      NaN        NaN     NaN     NaN
# 390074      NaN        NaN     NaN     NaN
# 390075      NaN        NaN     NaN     NaN
# 390076      NaN        NaN     NaN     NaN
# 390077      NaN        NaN     NaN     NaN
# 390078      NaN        NaN     NaN     NaN
# 390079      NaN        NaN     NaN     NaN
# 390080      NaN        NaN     NaN     NaN
#
# [10 rows x 46 columns]

# %%
# check unique values for columns that need binning

tblAccSub.WEATHER.unique()

# combine similar values

tblAccSub['WEATHER'] = tblAccSub['WEATHER'].replace(['Not Reported', 'Unknown'], 'NA')

tblAccSub.WEATHER.unique()
# Out:
# array(['Clear', 'Fog, Smog, Smoke', 'Cloudy', 'Severe Crosswinds', 'Rain',
#        'Snow', 'Sleet, Hail (Freezing Rain or Drizzle)', 'Other', 'NA',
#        'Blowing Sand, Soil, Dirt', 'Sleet or Hail',
#        'Freezing Rain or Drizzle'], dtype=object)

# %%
# check unique values for columns that need binning

tblAccSub.WRK_ZONE.unique()

# combine similar values

tblAccSub['WRK_ZONE'] = tblAccSub['WRK_ZONE'].replace(['Not Reported', 'None', 'Work Zone, Type Unknown'], 'NA')

tblAccSub.WRK_ZONE.unique()
# Out:
# array(['NA', 'Construction', 'Maintenance', 'Utility'], dtype=object)

# %%
# now to add the county and city names

# step 1: add table with values

tblCodes = pd.read_csv("city_codes.csv")

# only care about NC

tblCodesSub = tblCodes[tblCodes.State_Name == 'NORTH CAROLINA'] 

# get county

tblCodesCounty = tblCodesSub[['COUNTY', 'County_Name']]

tblCodesCounty.head(10)

# get city

tblCodesCity = tblCodesSub[['CITY', 'City_Name']]

tblCodesCity.head(10)
# Out:
#        CITY    City_Name
# 24494    15  ABBOTTSBURG
# 24495    10     ABERDEEN
# 24496    20         ACME
# 24497    30        ADDOR
# 24498    40      ADVANCE
# 24499    50      AHOSKIE
# 24500    56     ALAMANCE
# 24501    60    ALBEMARLE
# 24502    63    ALBERTSON
# 24503    68    ALEXANDER

# %%
# merge those tables

tblCodesAll = pd.merge(tblAccSub, tblCodesCounty, on='COUNTY', how='left')
tblCodesAll = pd.merge(tblCodesAll, tblCodesCity, on= 'CITY', how = 'left')

tblCodesAll.head(100)

# Consider: might want to delete the codes in CITY and COUNTY now or later
# Idea: Add number for population ranking of county and category for region
# Out:
#      Index           STATE  COUNTY    MONTH  DAY             HOUR MINUTE  \
# 0   390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 1   390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 2   390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 3   390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 4   390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 5   390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 6   390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 7   390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 8   390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 9   390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 10  390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 11  390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 12  390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 13  390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 14  390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 15  390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 16  390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 17  390072  North Carolina      19  January   12    4:00pm-4:59pm     52
# 18  390073  North Carolina      25  January    8  11:00pm-11:59pm     19
# 19  390073  North Carolina      25  January    8  11:00pm-11:59pm     19
# 20  390073  North Carolina      25  January    8  11:00pm-11:59pm     19
# 21  390073  North Carolina      25  January    8  11:00pm-11:59pm     19
# 22  390073  North Carolina      25  January    8  11:00pm-11:59pm     19
# 23  390073  North Carolina      25  January    8  11:00pm-11:59pm     19
# 24  390073  North Carolina      25  January    8  11:00pm-11:59pm     19
# 25  390074  North Carolina      47  January    8    9:00pm-9:59pm     21
# 26  390074  North Carolina      47  January    8    9:00pm-9:59pm     21
# 27  390074  North Carolina      47  January    8    9:00pm-9:59pm     21
# 28  390074  North Carolina      47  January    8    9:00pm-9:59pm     21
# 29  390074  North Carolina      47  January    8    9:00pm-9:59pm     21
# ..     ...             ...     ...      ...  ...              ...    ...
# 70  390078  North Carolina      85  January   12    3:00am-3:59am     30
# 71  390078  North Carolina      85  January   12    3:00am-3:59am     30
# 72  390078  North Carolina      85  January   12    3:00am-3:59am     30
# 73  390078  North Carolina      85  January   12    3:00am-3:59am     30
# 74  390078  North Carolina      85  January   12    3:00am-3:59am     30
# 75  390078  North Carolina      85  January   12    3:00am-3:59am     30
# 76  390078  North Carolina      85  January   12    3:00am-3:59am     30
# 77  390078  North Carolina      85  January   12    3:00am-3:59am     30
# 78  390078  North Carolina      85  January   12    3:00am-3:59am     30
# 79  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 80  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 81  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 82  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 83  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 84  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 85  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 86  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 87  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 88  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 89  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 90  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 91  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 92  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 93  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 94  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 95  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 96  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 97  390079  North Carolina      89  January    2    1:00pm-1:59pm     57
# 98  390080  North Carolina     103  January   10    8:00pm-8:59pm     56
# 99  390080  North Carolina     103  January   10    8:00pm-8:59pm     56
#
#     VE_FORMS  PERSONS  PEDS  ... WEATHER1  \
# 0          2        2     0  ...    Clear
# 1          2        2     0  ...    Clear
# 2          2        2     0  ...    Clear
# 3          2        2     0  ...    Clear
# 4          2        2     0  ...    Clear
# 5          2        2     0  ...    Clear
# 6          2        2     0  ...    Clear
# 7          2        2     0  ...    Clear
# 8          2        2     0  ...    Clear
# 9          2        2     0  ...    Clear
# 10         2        2     0  ...    Clear
# 11         2        2     0  ...    Clear
# 12         2        2     0  ...    Clear
# 13         2        2     0  ...    Clear
# 14         2        2     0  ...    Clear
# 15         2        2     0  ...    Clear
# 16         2        2     0  ...    Clear
# 17         2        2     0  ...    Clear
# 18         1        2     0  ...    Clear
# 19         1        2     0  ...    Clear
# 20         1        2     0  ...    Clear
# 21         1        2     0  ...    Clear
# 22         1        2     0  ...    Clear
# 23         1        2     0  ...    Clear
# 24         1        2     0  ...    Clear
# 25         1        1     0  ...    Clear
# 26         1        1     0  ...    Clear
# 27         1        1     0  ...    Clear
# 28         1        1     0  ...    Clear
# 29         1        1     0  ...    Clear
# ..       ...      ...   ...  ...      ...
# 70         2        3     0  ...    Clear
# 71         2        3     0  ...    Clear
# 72         2        3     0  ...    Clear
# 73         2        3     0  ...    Clear
# 74         2        3     0  ...    Clear
# 75         2        3     0  ...    Clear
# 76         2        3     0  ...    Clear
# 77         2        3     0  ...    Clear
# 78         2        3     0  ...    Clear
# 79         2        5     0  ...    Clear
# 80         2        5     0  ...    Clear
# 81         2        5     0  ...    Clear
# 82         2        5     0  ...    Clear
# 83         2        5     0  ...    Clear
# 84         2        5     0  ...    Clear
# 85         2        5     0  ...    Clear
# 86         2        5     0  ...    Clear
# 87         2        5     0  ...    Clear
# 88         2        5     0  ...    Clear
# 89         2        5     0  ...    Clear
# 90         2        5     0  ...    Clear
# 91         2        5     0  ...    Clear
# 92         2        5     0  ...    Clear
# 93         2        5     0  ...    Clear
# 94         2        5     0  ...    Clear
# 95         2        5     0  ...    Clear
# 96         2        5     0  ...    Clear
# 97         2        5     0  ...    Clear
# 98         2        2     0  ...    Clear
# 99         2        2     0  ...    Clear
#
#                                 WEATHER2 WRK_ZONE              TYP_INT  \
# 0   No Additional Atmospheric Conditions     None  Not an Intersection
# 1   No Additional Atmospheric Conditions     None  Not an Intersection
# 2   No Additional Atmospheric Conditions     None  Not an Intersection
# 3   No Additional Atmospheric Conditions     None  Not an Intersection
# 4   No Additional Atmospheric Conditions     None  Not an Intersection
# 5   No Additional Atmospheric Conditions     None  Not an Intersection
# 6   No Additional Atmospheric Conditions     None  Not an Intersection
# 7   No Additional Atmospheric Conditions     None  Not an Intersection
# 8   No Additional Atmospheric Conditions     None  Not an Intersection
# 9   No Additional Atmospheric Conditions     None  Not an Intersection
# 10  No Additional Atmospheric Conditions     None  Not an Intersection
# 11  No Additional Atmospheric Conditions     None  Not an Intersection
# 12  No Additional Atmospheric Conditions     None  Not an Intersection
# 13  No Additional Atmospheric Conditions     None  Not an Intersection
# 14  No Additional Atmospheric Conditions     None  Not an Intersection
# 15  No Additional Atmospheric Conditions     None  Not an Intersection
# 16  No Additional Atmospheric Conditions     None  Not an Intersection
# 17  No Additional Atmospheric Conditions     None  Not an Intersection
# 18  No Additional Atmospheric Conditions     None  Not an Intersection
# 19  No Additional Atmospheric Conditions     None  Not an Intersection
# 20  No Additional Atmospheric Conditions     None  Not an Intersection
# 21  No Additional Atmospheric Conditions     None  Not an Intersection
# 22  No Additional Atmospheric Conditions     None  Not an Intersection
# 23  No Additional Atmospheric Conditions     None  Not an Intersection
# 24  No Additional Atmospheric Conditions     None  Not an Intersection
# 25  No Additional Atmospheric Conditions     None  Not an Intersection
# 26  No Additional Atmospheric Conditions     None  Not an Intersection
# 27  No Additional Atmospheric Conditions     None  Not an Intersection
# 28  No Additional Atmospheric Conditions     None  Not an Intersection
# 29  No Additional Atmospheric Conditions     None  Not an Intersection
# ..                                   ...      ...                  ...
# 70  No Additional Atmospheric Conditions     None  Not an Intersection
# 71  No Additional Atmospheric Conditions     None  Not an Intersection
# 72  No Additional Atmospheric Conditions     None  Not an Intersection
# 73  No Additional Atmospheric Conditions     None  Not an Intersection
# 74  No Additional Atmospheric Conditions     None  Not an Intersection
# 75  No Additional Atmospheric Conditions     None  Not an Intersection
# 76  No Additional Atmospheric Conditions     None  Not an Intersection
# 77  No Additional Atmospheric Conditions     None  Not an Intersection
# 78  No Additional Atmospheric Conditions     None  Not an Intersection
# 79  No Additional Atmospheric Conditions     None       T-Intersection
# 80  No Additional Atmospheric Conditions     None       T-Intersection
# 81  No Additional Atmospheric Conditions     None       T-Intersection
# 82  No Additional Atmospheric Conditions     None       T-Intersection
# 83  No Additional Atmospheric Conditions     None       T-Intersection
# 84  No Additional Atmospheric Conditions     None       T-Intersection
# 85  No Additional Atmospheric Conditions     None       T-Intersection
# 86  No Additional Atmospheric Conditions     None       T-Intersection
# 87  No Additional Atmospheric Conditions     None       T-Intersection
# 88  No Additional Atmospheric Conditions     None       T-Intersection
# 89  No Additional Atmospheric Conditions     None       T-Intersection
# 90  No Additional Atmospheric Conditions     None       T-Intersection
# 91  No Additional Atmospheric Conditions     None       T-Intersection
# 92  No Additional Atmospheric Conditions     None       T-Intersection
# 93  No Additional Atmospheric Conditions     None       T-Intersection
# 94  No Additional Atmospheric Conditions     None       T-Intersection
# 95  No Additional Atmospheric Conditions     None       T-Intersection
# 96  No Additional Atmospheric Conditions     None       T-Intersection
# 97  No Additional Atmospheric Conditions     None       T-Intersection
# 98  No Additional Atmospheric Conditions     None  Not an Intersection
# 99  No Additional Atmospheric Conditions     None  Not an Intersection
#
#    PVH_INVL PERNOTMVIT PERMVIT RUR_URB County_Name City_Name
# 0       NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 1       NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 2       NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 3       NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 4       NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 5       NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 6       NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 7       NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 8       NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 9       NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 10      NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 11      NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 12      NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 13      NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 14      NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 15      NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 16      NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 17      NaN        NaN     NaN     NaN   BRUNSWICK       NaN
# 18      NaN        NaN     NaN     NaN    CABARRUS   CONCORD
# 19      NaN        NaN     NaN     NaN    CABARRUS   CONCORD
# 20      NaN        NaN     NaN     NaN    CABARRUS   CONCORD
# 21      NaN        NaN     NaN     NaN    CABARRUS   CONCORD
# 22      NaN        NaN     NaN     NaN    CABARRUS   CONCORD
# 23      NaN        NaN     NaN     NaN    CABARRUS   CONCORD
# 24      NaN        NaN     NaN     NaN    CABARRUS   CONCORD
# 25      NaN        NaN     NaN     NaN    COLUMBUS       NaN
# 26      NaN        NaN     NaN     NaN    COLUMBUS       NaN
# 27      NaN        NaN     NaN     NaN    COLUMBUS       NaN
# 28      NaN        NaN     NaN     NaN    COLUMBUS       NaN
# 29      NaN        NaN     NaN     NaN    COLUMBUS       NaN
# ..      ...        ...     ...     ...         ...       ...
# 70      NaN        NaN     NaN     NaN     HARNETT       NaN
# 71      NaN        NaN     NaN     NaN     HARNETT       NaN
# 72      NaN        NaN     NaN     NaN     HARNETT       NaN
# 73      NaN        NaN     NaN     NaN     HARNETT       NaN
# 74      NaN        NaN     NaN     NaN     HARNETT       NaN
# 75      NaN        NaN     NaN     NaN     HARNETT       NaN
# 76      NaN        NaN     NaN     NaN     HARNETT       NaN
# 77      NaN        NaN     NaN     NaN     HARNETT       NaN
# 78      NaN        NaN     NaN     NaN     HARNETT       NaN
# 79      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 80      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 81      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 82      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 83      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 84      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 85      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 86      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 87      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 88      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 89      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 90      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 91      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 92      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 93      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 94      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 95      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 96      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 97      NaN        NaN     NaN     NaN   HENDERSON       NaN
# 98      NaN        NaN     NaN     NaN       JONES       NaN
# 99      NaN        NaN     NaN     NaN       JONES       NaN
#
# [100 rows x 48 columns]
